# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.lincolnapts.com/properties/cityscape-st-louis-park-mn/'

# %%
page = requests.get(url)

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 9]> <html class="html-properties-cityscape-st-louis-park-mn no-js lt-ie-10 ie9" lang="en"> <![endif]-->\n<!--[if gt IE 9]><!-->\n\n\n\n\n<html class=\'html-properties-cityscape-st-louis-park-mn\' lang=\'en\'>\n<!--<![endif]-->\n<head>\n<meta charset=\'utf-8\'>\n<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<meta content=\'initial-scale=1\' name=\'viewport\'>\n<title>\nLincoln Property Company - Properties - Cityscape Apartments\n</title>\n<meta content=\'Experience a Lincoln Property Company apartment home today! Explore apartments for rent by location, floor plans, amenities, and neighborhood. Welcome Home!\' name=\'description\'>\n\n\n\n\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(\n{\'gtm.start\': new Date().getTime(),event:\'gtm.js\'}\n);var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js
# ...

# %%
BeautifulSoup(page.content)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 9]> <html class="html-properties-cityscape-st-louis-park-mn no-js lt-ie-10 ie9" lang="en"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="html-properties-cityscape-st-louis-park-mn" lang="en">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="initial-scale=1" name="viewport"/>
# <title>
# Lincoln Property Company - Properties - Cityscape Apartments
# </title>
# <meta content="Experience a Lincoln Property Company apartment home today! Explore apartments for rent by location, floor plans, amenities, and neighborhood. Welcome Home!" name="description"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
# {'gtm.start': new Date().getTime(),event:'gtm.js'}
# );var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
place_name = soup.find(attrs = {'class': "prop-top-name"}).text

# %%
Address = soup.find(attrs = {'class': "prop-top-address"}).text.replace('\n', "")

# %%
phone_no = soup.find(attrs = {'class': "prop-top-phone"}).text.replace('\n', "")

# %%
bedroom = soup.find(attrs = {'class': "info-copy floorplans-info"}).text.replace('\n', "")

# %%
no_of_unit = soup.find(attrs = {'class': "info-header"}).text.replace('\n', "")
# Out:
# '5707 Highway 7 St. Louis Park, MN 55416'

# %%
bedroom = soup.find(attrs = {'class': "info-copy floorplans-info"}).text.replace('\n', "")

# %%
bedroom = soup.find(attrs = {'class': "info-copy floorplans-info"}).text.replace('\n', "")

# %%
bedroom = soup.find(attrs = {'class': "info-copy floorplans-info"}).text.replace('\n', "")

# %%
data = soup.find(attrs = {'class': "content"})

# %%
prop-top-address
# Out:
# 'Cityscape Apartments'

# %%
Name = data.text

# %%
Name
# Out:
# 'Cityscape Apartments'

# %%
data = soup.find(attrs = {'class': "ng-binding"})

# %%
data
