# %%
import pandas as pd
from selenium import webdriver

# %%
df = pd.read_csv(r"uszips.csv")

# %%
webpage = r"https://www.lincolnapts.com/"

# %%
import urllib.request as urlRequest
import urllib.parse as urlParse

url = "https://www.lincolnapts.com/"
values = {"name": "601"}

# pretend to be a chrome 47 browser on a windows 10 machine
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36"}

# encode values for the url
params = urlParse.urlencode(values).encode("utf-8")

# create the url
targetUrl = urlRequest.Request(url=url, data=params, headers=headers)

# open the url
x  = urlRequest.urlopen(targetUrl)

# read the response
respone = x.read()
print(respone)
# Out:
# b'<!DOCTYPE html>\n<!--[if IE 9]> <html class="html-home no-js lt-ie-10 ie9" lang="en"> <![endif]-->\n<!--[if gt IE 9]><!-->\n\n\n\n\n<html class=\'html-home\' lang=\'en\'>\n<!--<![endif]-->\n<head>\n<meta charset=\'utf-8\'>\n<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n<meta content=\'initial-scale=1\' name=\'viewport\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n\n\n\n\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(\n{\'gtm.start\': new Date().getTime(),event:\'gtm.js\'}\n);var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-5PZ8DT\');</script>\n<!-- End Google Tag Manager -->\n\n\n\n<link rel="stylesheet" media="all" href="https://fonts.googleapis.com/css2?family=Lato:wght@400;700&amp;family=Roboto:wght@300;400;
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# There is no [linux64] chromedriver for browser 91.0.4472 in cache
# Get LATEST driver version for 91.0.4472
# Trying to download new driver from https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_linux64.zip
# Driver has been saved in cache [/home/arbaaz/.wdm/drivers/chromedriver/linux64/91.0.4472.101]

# %%
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument('user-agent = Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36')
driver = webdriver.Chrome(chrome_options=options, executable_path=r'/home/arbaaz/.wdm/drivers/chromedriver/linux64/91.0.4472.19/chromedriver')
driver.get('https://www.google.co.in')

# %%
from selenium import webdriver

webpage = r"https://www.lincolnapts.com"
searchterm = 22323

# %%
a = driver.get(webpage)

# %%
print(a)
# Out:
# None

# %%
sbox = driver.find_element_by_class_name("ng-valid ng-isolate-scope ng-dirty ng-touched ng-valid-parse")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-17-ba7a0356cb04> in <module>()
# ----> 1 sbox = driver.find_element_by_class_name("ng-valid ng-isolate-scope ng-dirty ng-touched ng-valid-parse")
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in find_element_by_class_name(self, name)
#     553             element = driver.find_element_by_class_name('foo')
#     554         """
# --> 555         return self.find_element(by=By.CLASS_NAME, value=name)
#     556
#     557     def find_elements_by_class_name(self, name):
#
# /usr/local/lib/python3.6/dist-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     953         return self.execute(Command.FIND_ELEMENT, {
#     954             'using': by,
# --> 955             'value': value})['value']
#     956
# ...

# %%
sbox.send_keys(searchterm)

# %%
submit = driver.find_element_by_class_name("svg-inline--fa fa-search fa-w-16")

# %%
submit.click()
